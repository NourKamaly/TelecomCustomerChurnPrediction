# %%
import pandas as pd, os, numpy as np, warnings
from sklearn.model_selection import train_test_split
from sklearn.impute import KNNImputer
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../0. Dataset/Training set.csv')
df.head()
# Out:
#    CustomerID Churn  MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 0     3000002   Yes           24.00           219.0                  22.0
# 1     3000010   Yes           16.99            10.0                  17.0
# 2     3000014    No           38.00             8.0                  38.0
# 3     3000022    No           82.28          1312.0                  75.0
# 4     3000026   Yes           17.14             0.0                  17.0
#
#    DirectorAssistedCalls  OverageMinutes  RoamingCalls  PercChangeMinutes  \
# 0                   0.25             0.0           0.0             -157.0
# 1                   0.00             0.0           0.0               -4.0
# 2                   0.00             0.0           0.0               -2.0
# 3                   1.24             0.0           0.0              157.0
# 4                   0.00             0.0           0.0                0.0
#
#    PercChangeRevenues  ...  ReferralsMadeBySubscriber  IncomeGroup  \
# ...

# %%
df.shape
# Out:
# (51047, 58)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
features = df.drop(columns = ['Churn'])
labels = df['Churn']
x_train,x_validation, y_train,y_validation = train_test_split(features, labels, test_size = 0.2, stratify = labels, random_state=42)
x_train['Churn'], x_validation['Churn'] = y_train, y_validation
x_validation.to_csv('../0. Dataset/Validation set.csv',index=False)
x_train.to_csv('../0. Dataset/Training set after splitting.csv',index=False)
# Out:
# C:\Users\NOURKA~1\AppData\Local\Temp/ipykernel_11056/2569965459.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_train['Churn'], x_validation['Churn'] = y_train, y_validation

# %%
df = pd.read_csv('../0. Dataset/Training set after splitting.csv')
df.drop(columns = ['CustomerID'],axis=1,inplace=True)

# %%
df.dtypes
# Out:
# CustomerID                     int64
# MonthlyRevenue               float64
# MonthlyMinutes               float64
# TotalRecurringCharge         float64
# DirectorAssistedCalls        float64
# OverageMinutes               float64
# RoamingCalls                 float64
# PercChangeMinutes            float64
# PercChangeRevenues           float64
# DroppedCalls                 float64
# BlockedCalls                 float64
# UnansweredCalls              float64
# CustomerCareCalls            float64
# ThreewayCalls                float64
# ReceivedCalls                float64
# OutboundCalls                float64
# InboundCalls                 float64
# PeakCallsInOut               float64
# OffPeakCallsInOut            float64
# DroppedBlockedCalls          float64
# CallForwardingCalls          float64
# CallWaitingCalls             float64
# MonthsInService                int64
# UniqueSubs                     int64
# ActiveSubs                     int64
# ...

# %%
df.isna().sum()
# Out:
# CustomerID                       0
# MonthlyRevenue                 120
# MonthlyMinutes                 120
# TotalRecurringCharge           120
# DirectorAssistedCalls          120
# OverageMinutes                 120
# RoamingCalls                   120
# PercChangeMinutes              290
# PercChangeRevenues             290
# DroppedCalls                     0
# BlockedCalls                     0
# UnansweredCalls                  0
# CustomerCareCalls                0
# ThreewayCalls                    0
# ReceivedCalls                    0
# OutboundCalls                    0
# InboundCalls                     0
# PeakCallsInOut                   0
# OffPeakCallsInOut                0
# DroppedBlockedCalls              0
# CallForwardingCalls              0
# CallWaitingCalls                 0
# MonthsInService                  0
# UniqueSubs                       0
# ActiveSubs                       0
# ServiceArea                     21
# Handsets                         1
# ...

# %%
def get_feature_percentage(df):
    size = df.shape[0]
    for column in df.columns:
        ctr = 0
        if df[column].dtype == np.dtype(object):
            for index in df[column].value_counts().index:
                    percentage = (int(df[column].value_counts()[ctr])/size)*100
                    print("Feature {feature} {index} represents {percentage} of the data".format(feature= column,index = index,percentage =percentage))
                    ctr += 1
            print('----------')

# %%
get_feature_percentage(df)
# Out:
# Feature ServiceArea NYCBRO917 represents 3.256850405269731 of the data
# Feature ServiceArea HOUHOU281 represents 3.016871954355119 of the data
# Feature ServiceArea DALDAL214 represents 2.926267845336337 of the data
# Feature ServiceArea NYCMAN917 represents 2.3410142762690698 of the data
# Feature ServiceArea DALFTW817 represents 1.5574111712417662 of the data
# Feature ServiceArea APCFCH703 represents 1.5304748145064524 of the data
# Feature ServiceArea SANSAN210 represents 1.4080368293459362 of the data
# Feature ServiceArea APCSIL301 represents 1.2880476038886304 of the data
# Feature ServiceArea SFROAK510 represents 1.2488674486372653 of the data
# Feature ServiceArea SANAUS512 represents 1.217033572495531 of the data
# Feature ServiceArea SFRSFR415 represents 1.1460195411024316 of the data
# Feature ServiceArea NYCQUE917 represents 1.050517912677229 of the data
# Feature ServiceArea ATLANE678 represents 1.0211327962387051 of the data
# ...

# %%
df['HandsetPrice'].unique()
# Out:
# array([nan, '150', '130', '10', '30', '80', '100', '200', '60', '40',
#        '400', '500', '300', '250', '180', '240'], dtype=object)

# %%
df['HandsetPrice'] = df['HandsetPrice'].replace('Unknown', np.nan)
df['MaritalStatus'] = df['MaritalStatus'].replace('Unknown', np.nan)

# %%
df.columns
# Out:
# Index(['MonthlyRevenue', 'MonthlyMinutes', 'TotalRecurringCharge',
#        'DirectorAssistedCalls', 'OverageMinutes', 'RoamingCalls',
#        'PercChangeMinutes', 'PercChangeRevenues', 'DroppedCalls',
#        'BlockedCalls', 'UnansweredCalls', 'CustomerCareCalls', 'ThreewayCalls',
#        'ReceivedCalls', 'OutboundCalls', 'InboundCalls', 'PeakCallsInOut',
#        'OffPeakCallsInOut', 'DroppedBlockedCalls', 'CallForwardingCalls',
#        'CallWaitingCalls', 'MonthsInService', 'UniqueSubs', 'ActiveSubs',
#        'ServiceArea', 'Handsets', 'HandsetModels', 'CurrentEquipmentDays',
#        'AgeHH1', 'AgeHH2', 'ChildrenInHH', 'HandsetRefurbished',
#        'HandsetWebCapable', 'TruckOwner', 'RVOwner', 'Homeownership',
#        'BuysViaMailOrder', 'RespondsToMailOffers', 'OptOutMailings',
#        'NonUSTravel', 'OwnsComputer', 'HasCreditCard', 'RetentionCalls',
#        'RetentionOffersAccepted', 'NewCellphoneUser', 'NotNewCellphoneUser',
# ...

# %% [markdown]
# handset price, marital status  has unknown as null value?
# multiple categorical features credit rating, occupation, prizmcode , service area

# %%
l = list(df.columns)

# %%
l.remove('MaritalStatus')

# %%
marriage_dataset = df.dropna(subset = l)

# %%
test_data = marriage_dataset[marriage_dataset['MaritalStatus'].isna()]

# %%
test_data.reset_index(drop=True,inplace=True)

# %%
train_data = marriage_dataset[marriage_dataset['MaritalStatus'].notna()]

# %%
yes_no_features = ['Churn','ChildrenInHH','HandsetRefurbished','HandsetWebCapable','TruckOwner','RVOwner','BuysViaMailOrder',
     'RespondsToMailOffers','OptOutMailings','NonUSTravel','OwnsComputer','HasCreditCard','NewCellphoneUser','NotNewCellphoneUser',
     'OwnsMotorcycle','MadeCallToRetentionTeam']

# %%
train_data
# Out:
#        MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 1               60.19           551.0                  60.0
# 5               50.00           403.0                  50.0
# 7              141.45           654.0                  20.0
# 8               62.85           524.0                  50.0
# 9               45.59           307.0                  30.0
# ...               ...             ...                   ...
# 40822           51.69           896.0                  50.0
# 40823           43.88           246.0                  40.0
# 40824           67.97           596.0                  40.0
# 40826           78.13           792.0                  45.0
# 40828           78.04           366.0                  45.0
#
#        DirectorAssistedCalls  OverageMinutes  RoamingCalls  PercChangeMinutes  \
# 1                       0.74             0.0           0.3              -88.0
# 5                       0.00             0.0           0.0               -8.0
# ...

# %%
yes_no_features = set(train_data.columns).intersection(set(yes_no_features))

# %%
yes_no_features
# Out:
# {'BuysViaMailOrder',
#  'ChildrenInHH',
#  'Churn',
#  'HandsetRefurbished',
#  'HandsetWebCapable',
#  'HasCreditCard',
#  'MadeCallToRetentionTeam',
#  'NewCellphoneUser',
#  'NonUSTravel',
#  'NotNewCellphoneUser',
#  'OptOutMailings',
#  'OwnsComputer',
#  'OwnsMotorcycle',
#  'RVOwner',
#  'RespondsToMailOffers',
#  'TruckOwner'}

# %%
for feature in yes_no_features:
    train_data[feature] = [1 if value == 'Yes' else 0 for value in train_data[feature]]

# %%
train_data['MaritalStatus'] = [1 if value == 'Yes' else 0 for value in train_data['MaritalStatus']]
